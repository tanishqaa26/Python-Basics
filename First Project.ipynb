# %%
# Out:
#   File "<ipython-input-4-713c9bb58d25>", line 1
#     print("Bubblegum"= $2)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
def prices():
  print(prices)

# %%
def product():
  print(product)

# %%
print(prices)
# Out:
# <function prices at 0x7819d01225f0>

# %%
print("Prices")
# Out:
# Prices

# %%
print("Bubblegum: $2")
# Out:
# Bubblegum: $2

# %%
print("Prices:")
print("Bubblegum: $2")
print("Toffee: $0.2")
print("Ice cream: $5")
print("Milk chocolate: $4")
print("Doughnut: $2.5")
print("Pancake: $3.2")
# Out:
# Prices:
# Bubblegum: $2
# Toffee: $0.2
# Ice cream: $5
# Milk chocolate: $4
# Doughnut: $2.5
# Pancake: $3.2

# %%
a= ''''I love animals!
Let's check on the animals
The deer looks fine.
The bat looks happy.
The lion looks healthy.'''''

print(a)
# Out:
# 'I love animals!
# Let's check on the animals
# The deer looks fine.
# The bat looks happy.
# The lion looks healthy.
